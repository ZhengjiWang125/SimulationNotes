# %%
'''
Process-based analysis
Arrival process:
    The arrival process is a collection of arrival events
    This process starts when the environment starts running and will be running nonstop
Service Process:
    There are several events for this process
        Request the server
        Get the server
        Engage with the server
        Release with sever
'''
# Out:
# '\nProcess-based analysis\nArrival process:\n    The arrival process is a collection of arrival events\n    This process starts when the environment starts running and will be running nonstop\nService Process:\n    There are several events for this process\n        Request the server\n        Get the server\n        Engage with the server\n        Release with sever\n'

# %%
import numpy as np
import simpy

from scipy.stats import uniform,expon

# %% [markdown]
# ### Example

# %% [markdown]
# simply ambulance get call and pick up patient

# %%
def arrival(env,ambulance):
    i = 0
    while True:
        dt = expon.rvs(scale = 1/1)
        yield env.timeout(dt)
        print(f"customer {i} has arrived at {env.now}")
        env.process(service(env,ambulance,i))
        i += 1
        
def service(env,ambulance,i):
    rqt = ambulance.request()
    print(f"customer {i} has {len(ambulance.queue)} before him")
    yield rqt
    print(f"customer {i} got to the ambulance")
    X = uniform.rvs()
    Y = uniform.rvs()
    dt = 2 * np.sqrt((X-0.5)**2 + (Y-0.5)**2)
    yield env.timeout(dt)
    print(f"customer {i} ends up in the hospotal")
    ambulance.release(rqt)


def system():
    env = simpy.Environment()
    ambulance = simpy.Resource(env,capacity = 1)    
    env.process(arrival(env,ambulance))
    env.run(until = 24)

# %%
system()
# Out:
# customer 0 has arrived at 0.5079296704013817
# customer 0 has 0 before him
# customer 0 got to the ambulance
# customer 1 has arrived at 0.549417088836322
# customer 1 has 1 before him
# customer 2 has arrived at 0.7420435322697135
# customer 2 has 2 before him
# customer 3 has arrived at 1.1069859062261382
# customer 3 has 3 before him
# customer 0 ends up in the hospotal
# customer 1 got to the ambulance
# customer 1 ends up in the hospotal
# customer 2 got to the ambulance
# customer 2 ends up in the hospotal
# customer 3 got to the ambulance
# customer 4 has arrived at 2.337091673246784
# customer 4 has 1 before him
# customer 5 has arrived at 2.585652114727575
# customer 5 has 2 before him
# customer 3 ends up in the hospotal
# customer 4 got to the ambulance
# customer 4 ends up in the hospotal
# customer 5 got to the ambulance
# customer 6 has arrived at 3.3974061258901416
# customer 6 has 1 before him
# customer 5 ends up in the hospotal
# customer 6 got to the ambulance
# customer 6 ends up in the hospotal
# customer 7 has arrived at 5.139905027476881
# customer 7 has 0 before him
# customer 7 got to the ambulance
# customer 8 has arrived at 5.376849294561854
# customer 8 has 1 before him
# customer 7 ends up in the hospotal
# customer 8 got to the ambulance
# customer 9 has arrived at 6.634847727850442
# customer 9 has 1 before him
# customer 10 has arrived at 6.869606522979522
# customer 10 has 2 before him
# customer 8 ends up in the hospotal
# customer 9 got to the ambulance
# customer 9 ends up in the hospotal
# customer 10 got to the ambulance
# customer 11 has arrived at 8.647219006369367
# customer 11 has 1 before him
# customer 10 ends up in the hospotal
# customer 11 got to the ambulance
# customer 12 has arrived at 9.28926687030297
# customer 12 has 1 before him
# customer 13 has arrived at 9.601889803016505
# customer 13 has 2 before him
# customer 11 ends up in the hospotal
# customer 12 got to the ambulance
# customer 14 has arrived at 10.148934819684312
# customer 14 has 2 before him
# customer 15 has arrived at 10.568085966877891
# customer 15 has 3 before him
# customer 12 ends up in the hospotal
# customer 13 got to the ambulance
# customer 13 ends up in the hospotal
# customer 14 got to the ambulance
# customer 16 has arrived at 11.680069367360232
# customer 16 has 2 before him
# customer 17 has arrived at 12.029662650244875
# customer 17 has 3 before him
# customer 14 ends up in the hospotal
# customer 15 got to the ambulance
# customer 18 has arrived at 12.721216098342916
# customer 18 has 3 before him
# customer 19 has arrived at 13.069056239773172
# customer 19 has 4 before him
# customer 20 has arrived at 13.137567690920827
# customer 20 has 5 before him
# customer 15 ends up in the hospotal
# customer 16 got to the ambulance
# customer 16 ends up in the hospotal
# customer 17 got to the ambulance
# customer 21 has arrived at 14.583284742867102
# customer 21 has 4 before him
# customer 22 has arrived at 14.812922760820092
# customer 22 has 5 before him
# customer 17 ends up in the hospotal
# customer 18 got to the ambulance
# customer 18 ends up in the hospotal
# customer 19 got to the ambulance
# customer 23 has arrived at 16.857033574264285
# customer 23 has 4 before him
# customer 24 has arrived at 16.888518752481723
# customer 24 has 5 before him
# customer 19 ends up in the hospotal
# customer 20 got to the ambulance
# customer 25 has arrived at 17.72423573926698
# customer 25 has 5 before him
# customer 26 has arrived at 18.244383831401215
# customer 26 has 6 before him
# customer 20 ends up in the hospotal
# customer 21 got to the ambulance
# customer 27 has arrived at 18.88922723464245
# customer 27 has 6 before him
# customer 21 ends up in the hospotal
# customer 22 got to the ambulance
# customer 28 has arrived at 19.377379620004916
# customer 28 has 6 before him
# customer 29 has arrived at 19.790164665450316
# customer 29 has 7 before him
# customer 22 ends up in the hospotal
# customer 23 got to the ambulance
# customer 30 has arrived at 20.035911146509317
# customer 30 has 7 before him
# customer 31 has arrived at 20.69592436204381
# customer 31 has 8 before him
# customer 23 ends up in the hospotal
# customer 24 got to the ambulance
# customer 32 has arrived at 21.01684354263405
# customer 32 has 8 before him
# customer 24 ends up in the hospotal
# customer 25 got to the ambulance
# customer 33 has arrived at 21.807747696709598
# customer 33 has 8 before him
# customer 25 ends up in the hospotal
# customer 26 got to the ambulance
# customer 34 has arrived at 22.160704880559948
# customer 34 has 8 before him
# customer 35 has arrived at 22.184795869310737
# customer 35 has 9 before him
# customer 26 ends up in the hospotal
# customer 27 got to the ambulance
# customer 36 has arrived at 22.84284945560336
# customer 36 has 9 before him
# customer 37 has arrived at 23.40633473976655
# customer 37 has 10 before him
# customer 27 ends up in the hospotal
# customer 28 got to the ambulance
# customer 28 ends up in the hospotal
# customer 29 got to the ambulance

# %% [markdown]
# add multiplier, also after an event the whole simulation stops

# %%
def arrival(env,ambulance,trip,stop):
    i = 0
    while True:
        dt = expon.rvs(scale = 1/1)
        yield env.timeout(dt)
        print(f"customer {i} has arrived at {env.now}")
        env.process(service(env,ambulance,i,trip,stop))
        i += 1
        
def service(env,ambulance,i,trip,stop):
    rqt = ambulance.request()
    print(f"customer {i} has {len(ambulance.queue)} before him")
    yield rqt
    print(f"customer {i} got to the ambulance")
    t0 = env.now
    X = uniform.rvs()
    Y = uniform.rvs()
    multiplier = 2.25 * uniform.rvs() + 0.75
    dt = multiplier * np.sqrt((X-0.5)**2 + (Y-0.5)**2)
    yield env.timeout(dt)
    t1 = env.now
    print(f"customer {i} ends up in the hospotal")
    ambulance.release(rqt)
    trip.append(t1-t0)
    if  np.sum(trip) > 4:
        stop.succeed()
        yield stop

        


def system():
    env = simpy.Environment()
    trip = []
    ambulance = simpy.Resource(env,capacity = 1)    
    stop = simpy.Event(env)
    env.process(arrival(env,ambulance, trip,stop))
    env.run(until = stop)
    return trip

# %%
system()
# Out:
# customer 0 has arrived at 0.7341396191769328
# customer 0 has 0 before him
# customer 0 got to the ambulance
# customer 0 ends up in the hospotal
# customer 1 has arrived at 1.5057188650954394
# customer 1 has 0 before him
# customer 1 got to the ambulance
# customer 2 has arrived at 2.3307409261544003
# customer 2 has 1 before him
# customer 3 has arrived at 2.792720271538062
# customer 3 has 2 before him
# customer 1 ends up in the hospotal
# customer 2 got to the ambulance
# customer 2 ends up in the hospotal
# customer 3 got to the ambulance
# customer 4 has arrived at 3.6353095030490885
# customer 4 has 1 before him
# customer 3 ends up in the hospotal
# customer 4 got to the ambulance
# customer 5 has arrived at 3.821543671819383
# customer 5 has 1 before him
# customer 4 ends up in the hospotal
# customer 5 got to the ambulance
# customer 5 ends up in the hospotal
# [0.42996700242995634,
#  1.5480005802817025,
#  0.32391219492876955,
#  0.419299636323494,
#  0.510231297933391,
#  1.1944964600355137]

# %% [markdown]
# When a call comes in, there is a timer, and if the timer runs out before ambulance heading towards that person, ambulance would drop them out by using rqt.cancel()

# %%
def arrival(env,ambulance,death):
    i = 0
    while True:
        dt = expon.rvs(scale = 1/1)
        yield env.timeout(dt)
        print(f"customer {i} has arrived at {env.now}")
        env.process(service(env,ambulance,i, death))
        i += 1
        
def service(env,ambulance,i, death):
    L = expon.rvs(scale = 4)
    rqt = ambulance.request()
    print(f"customer {i} has {len(ambulance.queue)} before him")
    result = yield rqt|env.timeout(L)
    if rqt not in result:
        rqt.cancel()
        death.append(i)
        print(f"customer {i} is dead")
    else:
        print(f"customer {i} got to the ambulance")
        X = uniform.rvs()
        Y = uniform.rvs()
        multiplier = 2.25 * uniform.rvs() + 0.75
        dt = multiplier * np.sqrt((X-0.5)**2 + (Y-0.5)**2) * 2
        yield env.timeout(dt)
        print(f"customer {i} ends up in the hospital")
        ambulance.release(rqt)


        


def system():
    env = simpy.Environment()
    death = []
    ambulance = simpy.Resource(env,capacity = 1)    
    env.process(arrival(env,ambulance, death))
    env.run(until = 24)
    return len(death)

# %%
system()
# Out:
# customer 0 has arrived at 0.5145653674298397
# customer 0 has 0 before him
# customer 0 got to the ambulance
# customer 0 ends up in the hospital
# customer 1 has arrived at 2.270182234220668
# customer 1 has 0 before him
# customer 1 got to the ambulance
# customer 2 has arrived at 3.1911892729415836
# customer 2 has 1 before him
# customer 1 ends up in the hospital
# customer 2 got to the ambulance
# customer 3 has arrived at 4.57438582303759
# customer 3 has 1 before him
# customer 4 has arrived at 5.173698425798574
# customer 4 has 2 before him
# customer 2 ends up in the hospital
# customer 3 got to the ambulance
# customer 3 ends up in the hospital
# customer 4 got to the ambulance
# customer 5 has arrived at 7.466041358182437
# customer 5 has 1 before him
# customer 6 has arrived at 7.628253271209242
# customer 6 has 2 before him
# customer 4 ends up in the hospital
# customer 5 got to the ambulance
# customer 6 is dead
# customer 7 has arrived at 8.871902292760087
# customer 7 has 1 before him
# customer 7 is dead
# customer 8 has arrived at 9.486612014530339
# customer 8 has 1 before him
# customer 9 has arrived at 9.553512366663226
# customer 9 has 2 before him
# customer 5 ends up in the hospital
# customer 8 got to the ambulance
# customer 8 ends up in the hospital
# customer 9 got to the ambulance
# customer 9 ends up in the hospital
# customer 10 has arrived at 12.069536024669468
# customer 10 has 0 before him
# customer 10 got to the ambulance
# customer 11 has arrived at 12.488186869601519
# customer 11 has 1 before him
# customer 12 has arrived at 12.749669493781155
# customer 12 has 2 before him
# customer 12 is dead
# customer 11 is dead
# customer 13 has arrived at 14.523941793792348
# customer 13 has 1 before him
# customer 10 ends up in the hospital
# customer 13 got to the ambulance
# customer 14 has arrived at 16.369589507096634
# customer 14 has 1 before him
# customer 13 ends up in the hospital
# customer 14 got to the ambulance
# customer 14 ends up in the hospital
# customer 15 has arrived at 18.420778695739635
# customer 15 has 0 before him
# customer 15 got to the ambulance
# customer 16 has arrived at 18.769062113057327
# customer 16 has 1 before him
# customer 17 has arrived at 18.99982223808835
# customer 17 has 2 before him
# customer 18 has arrived at 19.5731337055621
# customer 18 has 3 before him
# customer 19 has arrived at 19.685440314659456
# customer 19 has 4 before him
# customer 15 ends up in the hospital
# customer 16 got to the ambulance
# customer 18 is dead
# customer 19 is dead
# customer 20 has arrived at 20.795182626649357
# customer 20 has 2 before him
# customer 21 has arrived at 20.97457216587034
# customer 21 has 3 before him
# customer 22 has arrived at 21.07255997545376
# customer 22 has 4 before him
# customer 17 is dead
# customer 16 ends up in the hospital
# customer 20 got to the ambulance
# customer 20 ends up in the hospital
# customer 21 got to the ambulance
# customer 22 is dead
# customer 23 has arrived at 22.241877263352034
# customer 23 has 1 before him
# customer 21 ends up in the hospital
# customer 23 got to the ambulance
# 8

# %% [markdown]
# If I don't get to pick up someone with Li, they die.
# But even if they died afte I arrives, I will still heading to the hospital

# %%
def arrival(env,ambulance,death):
    i = 0
    while True:
        dt = expon.rvs(scale = 1/1)
        yield env.timeout(dt)
        print(f"customer {i} has arrived at {env.now}")
        env.process(service(env,ambulance,i, death))
        i += 1
        
def service(env,ambulance,i, death):
    L = expon.rvs(scale = 4)
    rqt = ambulance.request()
    t0 = env.now
    print(f"customer {i} has {len(ambulance.queue)} before him")
    result = yield rqt|env.timeout(L)
    if rqt not in result:
        rqt.cancel()
        death.append(i)
        print(f"customer {i} dies before ambulance")
    else:
        t1 = env.now
        passed = t1 - t0
        print(f"customer {i} got to the ambulance")
        X = uniform.rvs()
        Y = uniform.rvs()
        multiplier = 2.25 * uniform.rvs() + 0.75
        dt = multiplier * np.sqrt((X-0.5)**2 + (Y-0.5)**2) * 2
        die = env.timeout(L-passed)
        result = yield env.timeout(dt)| die
        if die in result:
            death.append(i)
            ambulance.release(rqt)
            print(f"customer {i} dies on the ambulance")
        else:
            print(f"customer {i} ends up in the hospital")
            ambulance.release(rqt)


        


def system():
    env = simpy.Environment()
    death = []
    ambulance = simpy.Resource(env,capacity = 1)    
    env.process(arrival(env,ambulance, death))
    env.run(until = 24)
    return len(death)

# %%
system()
# Out:
# customer 0 has arrived at 0.07712335653311571
# customer 0 has 0 before him
# customer 0 got to the ambulance
# customer 1 has arrived at 0.7002646617556648
# customer 1 has 1 before him
# customer 2 has arrived at 1.3459956134472255
# customer 2 has 2 before him
# customer 0 dies on the ambulance
# customer 1 got to the ambulance
# customer 3 has arrived at 1.8278746778938868
# customer 3 has 2 before him
# customer 4 has arrived at 2.903176813051504
# customer 4 has 3 before him
# customer 1 ends up in the hospital
# customer 2 got to the ambulance
# customer 2 ends up in the hospital
# customer 3 got to the ambulance
# customer 4 dies before ambulance
# customer 5 has arrived at 7.949506879727277
# customer 5 has 1 before him
# customer 3 ends up in the hospital
# customer 5 got to the ambulance
# customer 5 dies on the ambulance
# customer 6 has arrived at 9.435345564007706
# customer 6 has 0 before him
# customer 6 got to the ambulance
# customer 7 has arrived at 10.167279486289836
# customer 7 has 1 before him
# customer 8 has arrived at 10.224001881203113
# customer 8 has 2 before him
# customer 9 has arrived at 10.542420630246157
# customer 9 has 3 before him
# customer 7 dies before ambulance
# customer 6 ends up in the hospital
# customer 8 got to the ambulance
# customer 10 has arrived at 11.305945391775358
# customer 10 has 2 before him
# customer 9 dies before ambulance
# customer 11 has arrived at 11.888485533781607
# customer 11 has 2 before him
# customer 12 has arrived at 11.890121254101029
# customer 12 has 3 before him
# customer 8 dies on the ambulance
# customer 10 got to the ambulance
# customer 13 has arrived at 12.26141773144319
# customer 13 has 3 before him
# customer 14 has arrived at 12.88099719136681
# customer 14 has 4 before him
# customer 10 ends up in the hospital
# customer 11 got to the ambulance
# customer 14 dies before ambulance
# customer 15 has arrived at 14.11390417652178
# customer 15 has 3 before him
# customer 16 has arrived at 14.468170968893908
# customer 16 has 4 before him
# customer 11 dies on the ambulance
# customer 12 got to the ambulance
# customer 13 dies before ambulance
# customer 12 ends up in the hospital
# customer 15 got to the ambulance
# customer 16 dies before ambulance
# customer 15 dies on the ambulance
# customer 17 has arrived at 15.024528761145714
# customer 17 has 0 before him
# customer 17 got to the ambulance
# customer 17 ends up in the hospital
# customer 18 has arrived at 15.852419349956088
# customer 18 has 0 before him
# customer 18 got to the ambulance
# customer 18 dies on the ambulance
# customer 19 has arrived at 18.922044117378
# customer 19 has 0 before him
# customer 19 got to the ambulance
# customer 19 ends up in the hospital
# customer 20 has arrived at 21.081263592082507
# customer 20 has 0 before him
# customer 20 got to the ambulance
# customer 21 has arrived at 21.25993495539723
# customer 21 has 1 before him
# customer 20 ends up in the hospital
# customer 21 got to the ambulance
# customer 21 dies on the ambulance
# 13

# %% [markdown]
# Let's figure out something. Ambulance cost 100/hr while it is travelling. Each patient pays 500. dies gives 0. Find the expected earning

# %%
def arrival(env,ambulance,death,trip,revenue):
    i = 0
    while True:
        dt = expon.rvs(scale = 1/1)
        yield env.timeout(dt)
        print(f"customer {i} has arrived at {env.now}")
        env.process(service(env,ambulance,i, death,trip,revenue))
        i += 1
        
def service(env,ambulance,i, death,trip,revenue):
    L = expon.rvs(scale = 4)
    rqt = ambulance.request()
    t0 = env.now
    print(f"customer {i} has {len(ambulance.queue)} before him")
    result = yield rqt|env.timeout(L)
    if rqt not in result:
        rqt.cancel()
        death.append(i)
        print(f"customer {i} dies before ambulance")
    else:
        t1 = env.now
        passed = t1 - t0
        print(f"customer {i} got to the ambulance")
        X = uniform.rvs()
        Y = uniform.rvs()
        multiplier = 2.25 * uniform.rvs() + 0.75
        dt = multiplier * np.sqrt((X-0.5)**2 + (Y-0.5)**2) * 2
        die = env.timeout(L-passed)
        trip.append(dt)
        result = yield env.timeout(dt)| die
        if die in result:
            death.append(i)
            ambulance.release(rqt)
            print(f"customer {i} dies on the ambulance")
        else:
            print(f"customer {i} ends up in the hospital")
            revenue.append(500)
            ambulance.release(rqt)


        


def system():
    env = simpy.Environment()
    death = []
    trip = []
    revenue = []
    ambulance = simpy.Resource(env,capacity = 1)    
    env.process(arrival(env,ambulance, death,trip,revenue))
    env.run(until = 24)
    return np.sum(revenue) + np.sum(trip) * -100

# %%
system()
# Out:
# customer 0 has arrived at 1.4594942302854892
# customer 0 has 0 before him
# customer 0 got to the ambulance
# customer 1 has arrived at 1.714947709824084
# customer 1 has 1 before him
# customer 2 has arrived at 1.8224319409371146
# customer 2 has 2 before him
# customer 1 dies before ambulance
# customer 3 has arrived at 2.452370936568779
# customer 3 has 2 before him
# customer 4 has arrived at 3.044819566838173
# customer 4 has 3 before him
# customer 0 ends up in the hospital
# customer 2 got to the ambulance
# customer 5 has arrived at 3.418781292756923
# customer 5 has 3 before him
# customer 6 has arrived at 3.6958597168163836
# customer 6 has 4 before him
# customer 2 dies on the ambulance
# customer 3 got to the ambulance
# customer 3 ends up in the hospital
# customer 4 got to the ambulance
# customer 6 dies before ambulance
# customer 5 dies before ambulance
# customer 4 ends up in the hospital
# customer 7 has arrived at 7.268473130885663
# customer 7 has 0 before him
# customer 7 got to the ambulance
# customer 8 has arrived at 8.568705417317695
# customer 8 has 1 before him
# customer 9 has arrived at 8.65102987297491
# customer 9 has 2 before him
# customer 7 ends up in the hospital
# customer 8 got to the ambulance
# customer 10 has arrived at 12.04399298937319
# customer 10 has 2 before him
# customer 8 dies on the ambulance
# customer 9 got to the ambulance
# customer 9 ends up in the hospital
# customer 10 got to the ambulance
# customer 11 has arrived at 14.840638601338554
# customer 11 has 1 before him
# customer 10 ends up in the hospital
# customer 11 got to the ambulance
# customer 12 has arrived at 16.752931799611176
# customer 12 has 1 before him
# customer 11 ends up in the hospital
# customer 12 got to the ambulance
# customer 13 has arrived at 19.161171104157468
# customer 13 has 1 before him
# customer 13 dies before ambulance
# customer 14 has arrived at 19.620549410788993
# customer 14 has 1 before him
# customer 12 ends up in the hospital
# customer 14 got to the ambulance
# customer 14 dies on the ambulance
# customer 15 has arrived at 20.20060233795592
# customer 15 has 0 before him
# customer 15 got to the ambulance
# customer 16 has arrived at 20.41370798697721
# customer 16 has 1 before him
# customer 17 has arrived at 21.851757829583264
# customer 17 has 2 before him
# customer 15 dies on the ambulance
# customer 16 got to the ambulance
# customer 16 dies on the ambulance
# customer 17 got to the ambulance
# customer 18 has arrived at 23.59108290007725
# customer 18 has 1 before him
# 1415.701394673103

# %% [markdown]
# ## Hyperopt

# %%
'''
basically you need to define a function that returns a numeric value, 
the parameter needs to be a list
'''
# Out:
# '\nbasically you need to define a function that returns a numeric value, \nthe parameter needs to be a list\n'

# %%
import hyperopt
def objective(params):
    x = params[0]
    y = params[1]
    return -1 * (-(x + y + 12) ** 3 - y ** 4 + x ** 3)

# %% [markdown]
# quniform is suitable for discrete values while uniform is more suitable for continuous values

# %%
trials = hyperopt.Trials()
best = hyperopt.fmin(fn = objective,
                    space = [hyperopt.hp.uniform('x',-10,10), hyperopt.hp.quniform('y',-5,5,1)],
                    algo = hyperopt.tpe.suggest,
                    max_evals = 300,
                     trials = trials
                    )
# Out:
# 100%|█████████████████████████████████████████████| 300/300 [00:02<00:00, 146.81trial/s, best loss: 263.29605578355677]

# %%
print(best)
# Out:
# {'x': -4.541300965622645, 'y': -3.0}

# %% [markdown]
# ### demo: this is an example of using common random number and control variate

# %%
import hyperopt
import numpy as np
import simpy
from pynverse import inversefunc

from scipy.stats import expon, uniform, poisson
n = 100

from pynverse import inversefunc
def poisson_process(lmbda,T):
    N = poisson.rvs(lmbda * T)
    S = uniform.rvs(size = N) * T
    return np.sort(S)

def Lmbda(t):
    return 250 / np.pi * (1 - np.cos(np.pi * t / 10))

def inv(t):
    inv_1 = inversefunc(Lmbda, domain = [0,10], open_domain = [False, False])
    return inv_1(t)

def inv_method(Lmbda,t):
    Lambdat = Lmbda(t)
    S = poisson_process(1,Lambdat)
    return np.sort(inv(S))

arrivals = inv_method(Lmbda,10)
arrivals = np.concatenate((np.array([0]), arrivals))
arrival_interval = np.diff(arrivals)

lmbda = [20.,15.,1/15.] #checkout, kitchen, cost
def arrival(env,arrival_interval,checkouts,cooks,arrivals,departures,revenues,orders,checkout_time,kitchen_time):
    for i in range(len(arrival_interval)):
        dt = arrival_interval[i]
        yield env.timeout(dt)

        #print(f"customer {i} arrives at store at {env.now}")
        if len(checkouts.queue) > 5 or (len(cooks.queue) + cooks.count) > 10:
            revenues.append(-30)
            #print(f'customer {i} leaves becuase it is sick of this line')
        else:
            dt = expon.rvs(scale = np.power(lmbda,-1))
            env.process(checkout(dt,i,env,arrival_interval,checkouts,cooks,arrivals,departures,revenues,orders,checkout_time,kitchen_time))

def checkout(dt,i,env,arrival_interval,checkouts,cooks,arrivals,departures,revenues,orders,checkout_time,kitchen_time):
    price = dt[2]
    orders.append(dt[2])
    revenues.append(price)
    rqt = checkouts.request()
    # add to checkouts.queue or directly moved to users
    yield rqt # start being processed
    yield env.timeout(dt[0])
    checkout_time.append(dt[0])
    #print(f"customer {i} has finished checking out paying {price}, food order gone to kitchen ")
    checkouts.release(rqt)
    env.process(cook(dt,i,env,arrival_interval,checkouts,cooks,arrivals,departures,revenues,orders,checkout_time,kitchen_time))

def cook(dt,i,env,arrival_interval,checkouts,cooks,arrivals,departures,revenues,orders,checkout_time,kitchen_time):
    rqt = cooks.request()
    yield rqt
    yield env.timeout(dt[1])
    kitchen_time.append(dt[1])
    #print(f"customer {i} has gotten his food at {env.now} ")
    departures.append(env.now)
    cooks.release(rqt)

def system(n1,n2):
    env = simpy.Environment()
    checkouts = simpy.Resource(env,capacity = n1)
    cooks = simpy.Resource(env,capacity = n2)
    arrivals = inv_method(Lmbda,10)
    arrival_interval = np.diff(np.concatenate((np.array([0]), arrivals)))
    departures = []
    revenues = []
    orders = []
    checkout_time = []
    kitchen_time = []
    revenues.append(-n1 * 150)
    revenues.append(-n2 * 100)
    env.process(arrival(env,arrival_interval,checkouts,cooks,arrivals,departures,revenues,orders,checkout_time,kitchen_time))
    env.run()
    return sum(revenues),len(arrivals),np.mean(checkout_time),np.mean(kitchen_time),np.mean(orders)

def eval_revenue(n):
    np.random.seed(42)
    n1 = n[0]
    n2 = n[1]
    samples = [system(n1,n2) for i in range(100)]
    result = np.array(samples)
    x = result[:,0]
    z1 = result[:,1]
    z2 = result[:,2]
    z3 =  result[:,3]
    z4 = result[:,4]
    c1 = -np.cov(x,z1,ddof=1)[0,1]/np.var(z1,ddof = 1)
    c2 = -np.cov(x,z2,ddof=1)[0,1]/np.var(z2,ddof = 1)
    c3 = -np.cov(x,z3,ddof=1)[0,1]/np.var(z3,ddof = 1)
    c4 = -np.cov(x,z4,ddof=1)[0,1]/np.var(z4,ddof = 1)
    y = x + c1 * (z1 - Lmbda(10)) + c2 * (z2 - 1/20) + c3 * (z3 - 1/15) + c4 * (z4 - 15)
    return -np.mean(y)

best = hyperopt.fmin(fn = eval_revenue,
    space = [hyperopt.hp.quniform('n1',1,7,1), hyperopt.hp.quniform('n2',1,10,1)],
    algo = hyperopt.tpe.suggest,
    max_evals = 25)
print(best)
# Out:
# 100%|███████████████████████████████████████████████| 25/25 [01:30<00:00,  3.63s/trial, best loss: -1738.7294914396998]
# {'n1': 2.0, 'n2': 3.0}

# %% [markdown]
# ## Antithetic Method

# %%
'''
condition:
expectation is the same, variance is the same, and also negatively correlated

algo: suppose we have 2 inputs
generate r1, r2 random state
copy r1 , r2 to get r1c, r2c
use r1, r2 to generate xorigianl numbers
use r1c, r2c to generate anti numpyers
compute : y = (xoriginal+xanti)/2

'''
# Out:
# '\ncondition:\nexpectation is the same, variance is the same, and also negatively correlated\n\nalgo: suppose we have 2 inputs\ngenerate r1, r2 random state\ncopy r1 , r2 to get r1c, r2c\nuse r1, r2 to generate xorigianl numbers\nuse r1c, r2c to generate anti numpyers\ncompute : y = (xoriginal+xanti)/2\n\n'

# %%
import numpy as np
import simpy

from scipy.stats import expon

lambda_1 = 1.
lambda_2 = 1.

def arrival(env,server,T,anti):
    scale = np.power([lambda_1, lambda_2], -1)
    for i in range(0,100):
        dt = expon.rvs(scale = scale)
        if anti == True:
            dt = expon.ppf(1-expon.cdf(dt,scale = scale), scale = scale)
        yield env.timeout(dt[0])
        env.process(service(env,server,dt,T))

def service(env,server, dt,T):
    t0  = env.now
    rqt = server.request()
    yield rqt
    yield env.timeout(dt[1])
    server.release(rqt)
    t1 = env.now
    T.append(t1-t0)
        


def simulate(anti):
    T = []
    env  = simpy.Environment()
    server = simpy.Resource(env,capacity = 1)
    env.process(arrival(env,server,T,anti))
    env.run()
    return np.mean(T)


def eval_mean(n,seed):
    np.random.seed(seed)
    T_1 = [simulate(False) for i in range(0,n)]
    np.random.seed(seed)
    T_2 = [simulate(True) for i in range(0,n)]
    T_1 = np.array(T_1)
    T_2 = np.array(T_2)
    T_means = (T_1 + T_2)/2
    return np.mean(T_means)

# %%
eval_mean(100,42)
# Out:
# 7.879790550213511

# %% [markdown]
# ### when using hyperopt, always use common random number. Else, use antithetic

# %% [markdown]
# ## Common Random Number

# %%
'''
common random number is used when two things are negatively correlated.
For example,comparing difference

'''
# Out:
# '\ncommon random number is used when two things are negatively correlated.\nFor example,comparing difference\n\n'

# %%
lmbda = [20. , 10. , 30. , 10.]

def arrival(env, servers, T):
    i = 0
    while True:
        dt = expon.rvs(scale= np.power(lmbda,-1))
        if env.now + dt[0] > 1:
            break
        yield env.timeout(dt[0])
        env.process(service(env,servers,T,dt,i))
        i += 1
        
def service(env,servers,T,dt,i):
    t0 = env.now
    for j, server in enumerate(servers):
        rqt = server.request()
        yield rqt
        yield env.timeout(dt[j+1])
        server.release(rqt)
    t1 = env.now
    T.append(t1 - t0)






def simulate(n1,n2):
    T = []
    env = simpy.Environment()
    servers = [simpy.Resource(env,capacity = n1),
              simpy.Resource(env,capacity = n2),
              simpy.Resource(env,capacity = 20-n1-n2)]
    env.process(arrival(env,servers,T))
    env.run()
    return np.mean(T)

def eval_mean(n):
    np.random.seed(42)
    n1 = n[0]
    n2 = n[1]
    X = [simulate(n1,n2) for i in range(0,100)]
    return np.mean(X)

# %%
eval_mean([2,2])
# Out:
# 0.3360132492314921

# %%
best = hyperopt.fmin(fn = eval_mean, space = [hyperopt.hp.quniform('n1',1,9,1),hyperopt.hp.quniform('n2',1,9,1)],
                    algo = hyperopt.tpe.suggest,
                    max_evals = 25)
print(best)
# Out:
# 100%|███████████████████████████████████████████████| 25/25 [00:04<00:00,  5.94trial/s, best loss: 0.22936534918010282]
# {'n1': 7.0, 'n2': 5.0}

# %% [markdown]
# ## Control Variate

# %%
'''
as long as it is correlated, we can use control varaites

Algo:
Step 1: Generate a set of x samples and also a set of z samples
Step 2: c = -Cov(x,z)/Var(z)
Step 3: generate y using x + c(z - E(z))
Step 4: construc the confidence interval using the y samples

'''
# Out:
# '\nas long as it is correlated, we can use control varaites\n\nAlgo:\nStep 1: Generate a set of x samples and also a set of z samples\nStep 2: c = -Cov(x,z)/Var(z)\nStep 3: generate y using x + c(z - E(z))\nStep 4: construc the confidence interval using the y samples\n\n'

# %%
lmbda_1 = 1.
lmbda_2 = 1.

def arrival(env,server,T,IT,ST):
    scale = np.power([lmbda_1,lmbda_2],-1)
    for i in range(0,100):
        dt = expon.rvs(scale = scale)
        IT.append(dt[0])
        ST.append(dt[1])
        yield env.timeout(dt[0])
        env.process(service(env,server,dt,T))
        


def service(env,server,dt,T):
    t0 = env.now
    rqt = server.request()
    yield rqt
    yield env.timeout(dt[1])
    server.release(rqt)
    t1 = env.now
    T.append(t1 - t0)


def simulate():
    T = []
    IT = []
    ST = []
    env = simpy.Environment()
    server = simpy.Resource(env,capacity = 1)
    env.process(arrival(env,server,T, IT,ST))
    env.run()
    return np.mean(T), np.mean(IT),np.mean(ST)


def eval_mean(n):
    T_means = np.zeros(n)
    IT_means = np.zeros(n)
    ST_means = np.zeros(n)
    for i in range(0,n):
        t,it,st = simulate()
        T_means[i] = t
        IT_means[i] = it
        ST_means[i] = st
    c1 = -np.cov(T_means, IT_means)[0][1]/np.var(IT_means)
    c2 = -np.cov(T_means, IT_means)[0][1]/np.var(ST_means)
    T_tilde = T_means + c1 * (IT_means - 1/lmbda_1) + c2 * (ST_means - 1/ lmbda_2)
    return np.mean(T_tilde)

# %%
eval_mean(100)
# Out:
# 6.875938457735006

# %% [markdown]
# ## Conditioning

# %%
lmbda = 10
mu = 10
c = 300


def sample_M(n):
    M = np.zeros(n)
    for i in range(0,n):
        S_tmp = 0
        j = 0
        while S_tmp <= c:
            S_tmp += poisson.rvs(mu)
            j = j+1
        M[i] = j
    return M

def E_F_M(M):
    return 1 - poisson.cdf(M-1, lmbda)

M = sample_M(n)
efm = E_F_M(M)

print(np.mean(efm))
print(np.std(efm)/np.sqrt(n))
# Out:
# 3.705963630440401e-07
# 7.63993591897302e-08

# %%
lmbda_1 = 4.
lmbda_2 = 5.

np.random.seed(42)
def arrival(env,server,N):
    for i in range(0,10):
        dt = expon.rvs(scale = np.power([lmbda_1,lmbda_2],-1))
        yield env.timeout(dt[0])
        N.append(len(server.queue) + server.count)
        env.process(service(env,server,dt))
        
def service(env,server,dt):
    rqt = server.request()
    yield rqt
    yield env.timeout(dt[1])
    server.release(rqt)
    
def simulate():
    N = []
    env = simpy.Environment()
    server = simpy.Resource(env,capacity = 1)
    env.process(arrival(env,server,N))
    env.run()
    N = np.array(N)
    E_W = (N + 1) / lmbda_2
    return np.mean(E_W)

n = 100
T = [simulate() for i in range(n)]
print(np.mean(T))
print(np.std(T, ddof = 1)/np.sqrt(n))
# Out:
# 0.4482
# 0.017700299603696148

# %%
import hyperopt
import numpy as np
import simpy

from scipy.stats import uniform, expon
np.random.seed(42)

# %%
def arrivals(env,store,checkout,beefchef,veggiechef,profit, anti):
    i  = 0 
    while True:
        dt  = expon.rvs(scale = 1/40)
        U = uniform.rvs() #veggie or regular
        wait = expon.rvs(scale = 1/15) #checkout time
        if anti == True:
            dt = expon.ppf(1-expon.cdf(dt,scale = 1/40), scale = 1/40)
            U = 1- U
            wait = expon.ppf(1-expon.cdf(wait,scale = 1/15), scale = 1/15)
        yield env.timeout(dt)
        if U <= 0.2:
            order = 'veggie'
        else:
            order = 'beef'
        print(f"customer {i} has arrived at {env.now} ordering {order}")
        if env.now + dt < 8:
            if len(store.queue) + store.count < 20:
                env.process(service(env,store,checkout,beefchef,veggiechef,profit,order,wait,i))
            else:
                print(f"customer {i} left because too many people")
                profit.append(-5)
            i += 1
        else:
            break
        
            
def service(env,store,checkout,beefchef,veggiechef,profit,order,wait,i):
    rqt1 = store.request()
    rqt = checkout.request()
    yield rqt
    yield env.timeout(wait)
    print(f"customer {i} finished ordering")
    checkout.release(rqt)
    if order == 'veggie':
        env.process(kitchen_veggie(env,veggiechef,profit,i))
    else:
        env.process(kitchen_burger(env,beefchef,profit,i))
    store.release(rqt1)



def kitchen_burger(env,beefchef,profit,i):
    rqt = beefchef.request()
    yield rqt
    yield env.timeout(0.05)
    beefchef.release(rqt)
    profit.append(10)
    print(f"customer {i} got its beef burger at {env.now}")

def kitchen_veggie(env,veggiechef,profit,i):
    rqt = veggiechef.request()
    yield rqt
    yield env.timeout(0.1)
    veggiechef.release(rqt)
    profit.append(12)
    print(f"customer {i} got its veggie burger at {env.now}")

def simulate(n1,n2,n3,anti):
    env = simpy.Environment()
    checkout = simpy.Resource(env,capacity = n1)
    beefchef = simpy.Resource(env,capacity = n2)
    veggiechef = simpy.Resource(env,capacity = n3)
    store = simpy.Resource(env,capacity = 20)
    profit = []
    profit.append(-n1 * 120 - n2 * 120 - n3 * 120)
    env.process(arrivals(env,store,checkout,beefchef,veggiechef,profit, anti))
    env.run()
    return np.sum(profit)
    
    
def eval_mean(n):
    n[0] = n1
    n[1] = n2
    n[2] = n3
    np.random.seed(42)
    samples1 = [simulate(n1,n2,n3,False) for _ in range(50)]
    np.random.seed(42)
    samples2 = [simulate(n1,n2,n3,True) for _ in range(50)]
    samples = (samples1 + samples2)/2
    return np.mean(samples)

# %%
simulate(4,3,2,False)
# Out:
# customer 0 has arrived at 0.05579657552054569 ordering beef
# customer 1 has arrived at 0.06330473182422766 ordering beef
# customer 2 has arrived at 0.07110627456960948 ordering beef
# customer 0 finished ordering
# customer 3 has arrived at 0.0911829587324806 ordering beef
# customer 2 finished ordering
# customer 3 finished ordering
# customer 1 finished ordering
# customer 0 got its beef burger at 0.13368142919848117
# customer 2 got its beef burger at 0.15621534385493024
# customer 3 got its beef burger at 0.16443629041663615
# customer 4 has arrived at 0.1653146392612857 ordering beef
# customer 4 finished ordering
# customer 1 got its beef burger at 0.18368142919848118
# customer 5 has arrived at 0.2160272624542688 ordering beef
# customer 4 got its beef burger at 0.2253782724694871
# customer 6 has arrived at 0.2562451238025163 ordering beef
# customer 6 finished ordering
# customer 7 has arrived at 0.26406763749692846 ordering beef
# customer 8 has arrived at 0.27152400449515196 ordering veggie
# customer 6 got its beef burger at 0.30776016310101895
# customer 7 finished ordering
# customer 5 finished ordering
# customer 9 has arrived at 0.3755396085748328 ordering beef
# customer 7 got its beef burger at 0.3809807929592309
# customer 10 has arrived at 0.38348652036805614 ordering veggie
# customer 11 has arrived at 0.38661854646421123 ordering beef
# customer 9 finished ordering
# customer 8 finished ordering
# customer 12 has arrived at 0.40681443434938586 ordering beef
# customer 11 finished ordering
# customer 13 has arrived at 0.4125944975369992 ordering veggie
# customer 5 got its beef burger at 0.4159965618069183
# customer 13 finished ordering
# customer 9 got its beef burger at 0.4380965994855044
# customer 11 got its beef burger at 0.4579706350377307
# customer 14 has arrived at 0.4701637857583288 ordering beef
# customer 8 got its veggie burger at 0.49161647697264477
# customer 15 has arrived at 0.49310337872096244 ordering beef
# customer 15 finished ordering
# customer 13 got its veggie burger at 0.5224083689161586
# customer 12 finished ordering
# customer 14 finished ordering
# customer 10 finished ordering
# customer 16 has arrived at 0.554558617740245 ordering beef
# customer 15 got its beef burger at 0.5559581806301993
# customer 17 has arrived at 0.5728515410558119 ordering veggie
# customer 12 got its beef burger at 0.57484371384421
# customer 14 got its beef burger at 0.5808200731047617
# customer 17 finished ordering
# customer 16 finished ordering
# customer 18 has arrived at 0.606340018316411 ordering veggie
# customer 19 has arrived at 0.613377519156422 ordering beef
# customer 20 has arrived at 0.6243662310994934 ordering beef
# customer 19 finished ordering
# customer 16 got its beef burger at 0.6367660043621028
# customer 21 has arrived at 0.6452573193671359 ordering beef
# customer 10 got its veggie burger at 0.64727908888096
# customer 20 finished ordering
# customer 18 finished ordering
# customer 17 got its veggie burger at 0.6849756547257634
# customer 19 got its beef burger at 0.6860876652866985
# customer 20 got its beef burger at 0.6978710004065302
# customer 22 has arrived at 0.7143053605549602 ordering beef
# customer 23 has arrived at 0.7150973525255666 ordering beef
# customer 24 has arrived at 0.7164172344780609 ordering beef
# customer 21 finished ordering
# customer 25 has arrived at 0.7265880314265134 ordering beef
# customer 26 has arrived at 0.7285407940713196 ordering beef
# customer 22 finished ordering
# customer 25 finished ordering
# customer 27 has arrived at 0.7576918604646481 ordering beef
# customer 21 got its beef burger at 0.7679017142399812
# customer 18 got its veggie burger at 0.7679534995820854
# customer 23 finished ordering
# customer 26 finished ordering
# customer 27 finished ordering
# customer 24 finished ordering
# customer 22 got its beef burger at 0.7804384014378967
# customer 25 got its beef burger at 0.7841026257441587
# customer 28 has arrived at 0.800437452928928 ordering beef
# customer 29 has arrived at 0.8083787933036288 ordering beef
# customer 30 has arrived at 0.8107800616687951 ordering beef
# customer 30 finished ordering
# customer 23 got its beef burger at 0.8253680626504398
# customer 26 got its beef burger at 0.8304384014378967
# customer 27 got its beef burger at 0.8341026257441587
# customer 29 finished ordering
# customer 24 got its beef burger at 0.8753680626504399
# customer 28 finished ordering
# customer 30 got its beef burger at 0.8804384014378968
# customer 31 has arrived at 0.8857923279968642 ordering beef
# customer 29 got its beef burger at 0.888232791675617
# customer 31 finished ordering
# customer 32 has arrived at 0.9053090741506576 ordering beef
# customer 28 got its beef burger at 0.9295340409095361
# customer 33 has arrived at 0.9463789198025016 ordering beef
# customer 31 got its beef burger at 0.949441013457762
# customer 32 finished ordering
# customer 34 has arrived at 0.9936732195037585 ordering beef
# customer 35 has arrived at 0.9999235477314116 ordering beef
# customer 36 has arrived at 1.0009291752615461 ordering beef
# customer 37 has arrived at 1.0059079958962425 ordering beef
# customer 38 has arrived at 1.0067713839848478 ordering beef
# customer 33 finished ordering
# customer 34 finished ordering
# customer 32 got its beef burger at 1.043149592759356
# customer 38 finished ordering
# customer 39 has arrived at 1.0713276007687398 ordering beef
# customer 33 got its beef burger at 1.0749491755452705
# customer 40 has arrived at 1.0873991358987012 ordering beef
# customer 34 got its beef burger at 1.0884877305818412
# customer 41 has arrived at 1.0970076489366896 ordering beef
# customer 38 got its beef burger at 1.1120140615648555
# customer 42 has arrived at 1.1196828649438848 ordering beef
# customer 43 has arrived at 1.1216847485264945 ordering beef
# customer 44 has arrived at 1.153938159457004 ordering veggie
# customer 45 has arrived at 1.1733237473170053 ordering beef
# customer 36 finished ordering
# customer 37 finished ordering
# customer 35 finished ordering
# customer 41 finished ordering
# customer 46 has arrived at 1.1979039744770594 ordering beef
# customer 42 finished ordering
# customer 47 has arrived at 1.2045343655512057 ordering veggie
# customer 48 has arrived at 1.2050718371552123 ordering beef
# customer 43 finished ordering
# customer 36 got its beef burger at 1.2238347457598966
# customer 44 finished ordering
# customer 37 got its beef burger at 1.2396735264869725
# customer 35 got its beef burger at 1.242154466886106
# customer 45 finished ordering
# customer 39 finished ordering
# customer 41 got its beef burger at 1.2738347457598966
# customer 49 has arrived at 1.2750216332250288 ordering beef
# customer 50 has arrived at 1.2858185986462358 ordering beef
# customer 42 got its beef burger at 1.2896735264869725
# customer 46 finished ordering
# customer 43 got its beef burger at 1.292154466886106
# customer 40 finished ordering
# customer 51 has arrived at 1.3021607812533655 ordering beef
# customer 48 finished ordering
# customer 45 got its beef burger at 1.3238347457598967
# customer 44 got its veggie burger at 1.3259703434787276
# customer 50 finished ordering
# customer 39 got its beef burger at 1.3396735264869726
# customer 46 got its beef burger at 1.342154466886106
# customer 40 got its beef burger at 1.3738347457598967
# customer 47 finished ordering
# customer 48 got its beef burger at 1.3896735264869726
# customer 50 got its beef burger at 1.3921544668861061
# customer 52 has arrived at 1.4056707071743983 ordering beef
# customer 53 has arrived at 1.4193474465698739 ordering beef
# customer 54 has arrived at 1.4222741133093904 ordering beef
# customer 55 has arrived at 1.431059480552698 ordering beef
# customer 56 has arrived at 1.4315103706234966 ordering beef
# customer 53 finished ordering
# customer 52 finished ordering
# customer 57 has arrived at 1.4436363388098796 ordering beef
# customer 55 finished ordering
# customer 51 finished ordering
# customer 54 finished ordering
# customer 57 finished ordering
# customer 47 got its veggie burger at 1.4815299999370937
# customer 56 finished ordering
# customer 53 got its beef burger at 1.487536054573847
# customer 52 got its beef burger at 1.4917296534138078
# customer 55 got its beef burger at 1.494596638809631
# customer 58 has arrived at 1.518510245153374 ordering beef
# customer 58 finished ordering
# customer 59 has arrived at 1.5320243645042089 ordering beef
# customer 51 got its beef burger at 1.537536054573847
# customer 54 got its beef burger at 1.5417296534138079
# customer 57 got its beef burger at 1.544596638809631
# customer 60 has arrived at 1.5477740505817437 ordering beef
# customer 60 finished ordering
# customer 56 got its beef burger at 1.587536054573847
# customer 58 got its beef burger at 1.591729653413808
# customer 60 got its beef burger at 1.6099582098655303
# customer 61 has arrived at 1.666010167734064 ordering beef
# customer 62 has arrived at 1.692230494220778 ordering beef
# customer 63 has arrived at 1.698786369922077 ordering veggie
# customer 49 finished ordering
# customer 64 has arrived at 1.7039447065109408 ordering beef
# customer 65 has arrived at 1.70543428171926 ordering beef
# customer 63 finished ordering
# customer 59 finished ordering
# customer 62 finished ordering
# customer 64 finished ordering
# customer 49 got its beef burger at 1.7519004048066884
# customer 66 has arrived at 1.7711256455644289 ordering beef
# customer 59 got its beef burger at 1.7750618047122644
# customer 67 has arrived at 1.783740191936776 ordering beef
# customer 66 finished ordering
# customer 68 has arrived at 1.7879180140566135 ordering beef
# customer 62 got its beef burger at 1.7901539443936074
# customer 69 has arrived at 1.7942522079058547 ordering beef
# customer 64 got its beef burger at 1.8019004048066884
# customer 68 finished ordering
# customer 70 has arrived at 1.8159448540440914 ordering veggie
# customer 63 got its veggie burger at 1.8185060647147222
# customer 71 has arrived at 1.8236623914857668 ordering veggie
# customer 66 got its beef burger at 1.8338612253361746
# customer 68 got its beef burger at 1.854862725205986
# customer 61 finished ordering
# customer 67 finished ordering
# customer 69 finished ordering
# customer 65 finished ordering
# customer 72 has arrived at 1.9015543003045987 ordering beef
# customer 61 got its beef burger at 1.9066774565003233
# customer 67 got its beef burger at 1.9131265520981984
# customer 69 got its beef burger at 1.9147823601517806
# customer 73 has arrived at 1.9281771128345642 ordering beef
# customer 73 finished ordering
# customer 74 has arrived at 1.9413024753323207 ordering beef
# customer 65 got its beef burger at 1.9566774565003233
# customer 74 finished ordering
# customer 75 has arrived at 1.9734338648322474 ordering beef
# customer 75 finished ordering
# customer 76 has arrived at 1.9796512713617578 ordering beef
# customer 73 got its beef burger at 1.9842441059513876
# customer 76 finished ordering
# customer 70 finished ordering
# customer 71 finished ordering
# customer 74 got its beef burger at 2.0113539702307395
# customer 72 finished ordering
# customer 77 has arrived at 2.027281236937863 ordering beef
# customer 75 got its beef burger at 2.029068494647951
# customer 76 got its beef burger at 2.034930260708085
# customer 78 has arrived at 2.049718438852565 ordering beef
# customer 72 got its beef burger at 2.0621001316201726
# customer 77 finished ordering
# customer 79 has arrived at 2.078049786300636 ordering beef
# customer 78 finished ordering
# customer 70 got its veggie burger at 2.0966324439197517
# customer 79 finished ordering
# customer 71 got its veggie burger at 2.109523758663534
# customer 77 got its beef burger at 2.120951579433569
# customer 78 got its beef burger at 2.128212981115579
# customer 80 has arrived at 2.130772572186645 ordering beef
# customer 79 got its beef burger at 2.1487596626740406
# customer 81 has arrived at 2.1782977151501854 ordering beef
# customer 80 finished ordering
# customer 82 has arrived at 2.223649886415709 ordering beef
# customer 83 has arrived at 2.2477482968912637 ordering beef
# customer 80 got its beef burger at 2.25239034347897
# customer 83 finished ordering
# customer 81 finished ordering
# customer 82 finished ordering
# customer 84 has arrived at 2.3009369548425673 ordering beef
# customer 84 finished ordering
# customer 83 got its beef burger at 2.3092612419220155
# customer 81 got its beef burger at 2.310447403210806
# customer 85 has arrived at 2.3446281392494503 ordering veggie
# customer 82 got its beef burger at 2.3496415058642994
# customer 84 got its beef burger at 2.3592612419220154
# customer 85 finished ordering
# customer 86 has arrived at 2.378644609328469 ordering veggie
# customer 87 has arrived at 2.4232593667537747 ordering beef
# customer 87 finished ordering
# customer 88 has arrived at 2.4317175503215713 ordering beef
# customer 89 has arrived at 2.456696694048798 ordering beef
# customer 85 got its veggie burger at 2.471837938083404
# customer 87 got its beef burger at 2.473686456661602
# customer 90 has arrived at 2.47610911921824 ordering beef
# customer 90 finished ordering
# customer 86 finished ordering
# customer 91 has arrived at 2.5118943312366517 ordering beef
# customer 92 has arrived at 2.5223532334863794 ordering beef
# customer 89 finished ordering
# customer 93 has arrived at 2.525057058428011 ordering beef
# customer 94 has arrived at 2.526813249685289 ordering beef
# customer 95 has arrived at 2.528556397870158 ordering beef
# customer 90 got its beef burger at 2.5336522537046284
# customer 96 has arrived at 2.552806302632029 ordering veggie
# customer 89 got its beef burger at 2.5737058625782345
# customer 86 got its veggie burger at 2.592215770805707
# customer 93 finished ordering
# customer 97 has arrived at 2.643561162010638 ordering beef
# customer 98 has arrived at 2.647045191981483 ordering beef
# customer 99 has arrived at 2.647604490674845 ordering beef
# customer 93 got its beef burger at 2.652682783998542
# customer 100 has arrived at 2.6843907137394414 ordering beef
# customer 94 finished ordering
# customer 101 has arrived at 2.6923829928034015 ordering beef
# customer 88 finished ordering
# customer 92 finished ordering
# customer 102 has arrived at 2.707392044014015 ordering veggie
# customer 95 finished ordering
# customer 98 finished ordering
# customer 91 finished ordering
# customer 94 got its beef burger at 2.734788850339963
# customer 103 has arrived at 2.7369703499649294 ordering beef
# customer 88 got its beef burger at 2.746595114853198
# customer 92 got its beef burger at 2.7515972985242825
# customer 99 finished ordering
# customer 104 has arrived at 2.7654952454833603 ordering beef
# customer 100 finished ordering
# customer 95 got its beef burger at 2.7847888503399627
# customer 97 finished ordering
# customer 101 finished ordering
# customer 98 got its beef burger at 2.796595114853198
# customer 103 finished ordering
# customer 91 got its beef burger at 2.8015972985242823
# customer 104 finished ordering
# customer 96 finished ordering
# customer 99 got its beef burger at 2.8347888503399625
# customer 105 has arrived at 2.840824105642988 ordering veggie
# customer 100 got its beef burger at 2.846595114853198
# customer 97 got its beef burger at 2.851597298524282
# customer 102 finished ordering
# customer 105 finished ordering
# customer 101 got its beef burger at 2.8847888503399624
# customer 103 got its beef burger at 2.8965951148531977
# customer 104 got its beef burger at 2.901597298524282
# customer 106 has arrived at 2.9127133164629795 ordering beef
# customer 107 has arrived at 2.925383924038208 ordering beef
# customer 96 got its veggie burger at 2.9334026378449924
# customer 108 has arrived at 2.9385465384343434 ordering beef
# customer 109 has arrived at 2.944538040468815 ordering veggie
# customer 108 finished ordering
# customer 110 has arrived at 2.95603051682312 ordering beef
# customer 102 got its veggie burger at 2.976617862290031
# customer 106 finished ordering
# customer 110 finished ordering
# customer 108 got its beef burger at 3.005966925933269
# customer 109 finished ordering
# customer 106 got its beef burger at 3.030550984311653
# customer 105 got its veggie burger at 3.0334026378449925
# customer 111 has arrived at 3.04223257535314 ordering veggie
# customer 110 got its beef burger at 3.048760724469974
# customer 112 has arrived at 3.0797020079699977 ordering beef
# customer 109 got its veggie burger at 3.114844431060548
# customer 113 has arrived at 3.115486810785091 ordering beef
# customer 114 has arrived at 3.1163134836188404 ordering beef
# customer 113 finished ordering
# customer 115 has arrived at 3.1561202970921314 ordering beef
# customer 116 has arrived at 3.1594638908200396 ordering beef
# customer 117 has arrived at 3.1650588826923305 ordering beef
# customer 113 got its beef burger at 3.1748664098469295
# customer 111 finished ordering
# customer 115 finished ordering
# customer 118 has arrived at 3.1868640185004544 ordering beef
# customer 114 finished ordering
# customer 117 finished ordering
# customer 119 has arrived at 3.1961537284299593 ordering beef
# customer 120 has arrived at 3.1980338589876265 ordering beef
# customer 107 finished ordering
# customer 119 finished ordering
# customer 112 finished ordering
# customer 121 has arrived at 3.2209424115749243 ordering beef
# customer 116 finished ordering
# customer 115 got its beef burger at 3.2358635532800677
# customer 114 got its beef burger at 3.238786922475648
# customer 117 got its beef burger at 3.2432111258618788
# customer 120 finished ordering
# customer 122 has arrived at 3.270117099185002 ordering beef
# customer 122 finished ordering
# customer 111 got its veggie burger at 3.277544942335134
# customer 107 got its beef burger at 3.2858635532800675
# customer 123 has arrived at 3.2864896452225545 ordering veggie
# customer 119 got its beef burger at 3.288786922475648
# customer 112 got its beef burger at 3.2932111258618786
# customer 118 finished ordering
# customer 121 finished ordering
# customer 123 finished ordering
# customer 116 got its beef burger at 3.3358635532800673
# customer 120 got its beef burger at 3.3387869224756477
# customer 122 got its beef burger at 3.3432111258618784
# customer 118 got its beef burger at 3.385863553280067
# customer 121 got its beef burger at 3.3887869224756475
# customer 124 has arrived at 3.3944192116032905 ordering veggie
# customer 123 got its veggie burger at 3.404965064074869
# customer 125 has arrived at 3.418487772477323 ordering beef
# customer 126 has arrived at 3.418733244861937 ordering beef
# customer 127 has arrived at 3.421032467789538 ordering beef
# customer 128 has arrived at 3.4230784100297402 ordering beef
# customer 127 finished ordering
# customer 128 finished ordering
# customer 124 finished ordering
# customer 129 has arrived at 3.4440350951276932 ordering beef
# customer 130 has arrived at 3.4496183794841393 ordering veggie
# customer 130 finished ordering
# customer 126 finished ordering
# customer 125 finished ordering
# customer 127 got its beef burger at 3.473283590836573
# customer 131 has arrived at 3.4749129823517424 ordering beef
# customer 131 finished ordering
# customer 128 got its beef burger at 3.482776157898217
# customer 126 got its beef burger at 3.5173474511001155
# customer 125 got its beef burger at 3.5232835908365727
# customer 131 got its beef burger at 3.532776157898217
# customer 124 got its veggie burger at 3.5404809420172243
# customer 132 has arrived at 3.5437178337129653 ordering veggie
# customer 129 finished ordering
# customer 130 got its veggie burger at 3.5569816339698113
# customer 133 has arrived at 3.574583833814496 ordering beef
# customer 132 finished ordering
# customer 129 got its beef burger at 3.601526809735077
# customer 134 has arrived at 3.615036730629414 ordering beef
# customer 135 has arrived at 3.6171243918733684 ordering beef
# customer 133 finished ordering
# customer 136 has arrived at 3.6596218321150062 ordering beef
# customer 135 finished ordering
# customer 137 has arrived at 3.6783067774639755 ordering beef
# customer 138 has arrived at 3.6798630282469507 ordering beef
# customer 137 finished ordering
# customer 138 finished ordering
# customer 132 got its veggie burger at 3.6956745595860068
# customer 133 got its beef burger at 3.708054998672631
# customer 135 got its beef burger at 3.720002504065297
# customer 134 finished ordering
# customer 136 finished ordering
# customer 139 has arrived at 3.7312139171720107 ordering beef
# customer 137 got its beef burger at 3.7339837707899055
# customer 140 has arrived at 3.7414844952802966 ordering veggie
# customer 138 got its beef burger at 3.758054998672631
# customer 141 has arrived at 3.7683599004138344 ordering beef
# customer 134 got its beef burger at 3.777467035252609
# customer 136 got its beef burger at 3.7839837707899053
# customer 142 has arrived at 3.8001128739070587 ordering beef
# customer 141 finished ordering
# customer 140 finished ordering
# customer 141 got its beef burger at 3.8723931203548756
# customer 143 has arrived at 3.892128873354311 ordering beef
# customer 143 finished ordering
# customer 144 has arrived at 3.9206325682361953 ordering veggie
# customer 144 finished ordering
# customer 145 has arrived at 3.9280820370646676 ordering beef
# customer 140 got its veggie burger at 3.9454320351199197
# customer 143 got its beef burger at 3.956966991918904
# customer 146 has arrived at 3.9605546115351147 ordering beef
# customer 147 has arrived at 3.9711683248523517 ordering beef
# customer 148 has arrived at 3.97219171840345 ordering beef
# customer 139 finished ordering
# customer 149 has arrived at 3.9866254454293166 ordering beef
# customer 146 finished ordering
# customer 144 got its veggie burger at 4.022708042671103
# customer 139 got its beef burger at 4.029487437800951
# customer 150 has arrived at 4.038298103961011 ordering beef
# customer 151 has arrived at 4.046400801638139 ordering beef
# customer 146 got its beef burger at 4.047504183495609
# customer 152 has arrived at 4.05231482411189 ordering beef
# customer 148 finished ordering
# customer 145 finished ordering
# customer 153 has arrived at 4.085338074490061 ordering veggie
# customer 149 finished ordering
# customer 150 finished ordering
# customer 148 got its beef burger at 4.10512763291912
# customer 145 got its beef burger at 4.113216698744057
# customer 154 has arrived at 4.145269404647292 ordering veggie
# customer 149 got its beef burger at 4.149583253159068
# customer 150 got its beef burger at 4.15512763291912
# customer 152 finished ordering
# customer 142 finished ordering
# customer 154 finished ordering
# customer 152 got its beef burger at 4.216295145516028
# customer 142 got its beef burger at 4.2240216227102385
# customer 155 has arrived at 4.23412383061883 ordering veggie
# customer 153 finished ordering
# customer 156 has arrived at 4.251069354182669 ordering beef
# customer 151 finished ordering
# customer 157 has arrived at 4.265802787321668 ordering beef
# customer 147 finished ordering
# customer 158 has arrived at 4.288273320888795 ordering veggie
# customer 154 got its veggie burger at 4.292102262156049
# customer 157 finished ordering
# customer 151 got its beef burger at 4.311886982460641
# customer 158 finished ordering
# customer 147 got its beef burger at 4.322425030568717
# customer 157 got its beef burger at 4.345475451266855
# customer 153 got its veggie burger at 4.350172806124502
# customer 155 finished ordering
# customer 159 has arrived at 4.375452271934323 ordering beef
# customer 160 has arrived at 4.385285377044046 ordering beef
# customer 156 finished ordering
# customer 160 finished ordering
# customer 158 got its veggie burger at 4.421344714646359
# customer 156 got its beef burger at 4.437469754298992
# customer 160 got its beef burger at 4.444636495684722
# customer 159 finished ordering
# customer 155 got its veggie burger at 4.462576481802607
# customer 161 has arrived at 4.472800638404657 ordering beef
# customer 162 has arrived at 4.474709081468555 ordering veggie
# customer 163 has arrived at 4.484983708463685 ordering beef
# customer 161 finished ordering
# customer 164 has arrived at 4.492132939388081 ordering beef
# customer 165 has arrived at 4.496702238080227 ordering veggie
# customer 159 got its beef burger at 4.496736097568797
# customer 165 finished ordering
# customer 163 finished ordering
# customer 162 finished ordering
# customer 166 has arrived at 4.530035491099972 ordering beef
# customer 161 got its beef burger at 4.540750874637838
# customer 163 got its beef burger at 4.572562187842724
# customer 166 finished ordering
# customer 164 finished ordering
# customer 167 has arrived at 4.5765103033668755 ordering beef
# customer 165 got its veggie burger at 4.599192953280858
# customer 166 got its beef burger at 4.622945769075658
# customer 162 got its veggie burger at 4.62360897116386
# customer 164 got its beef burger at 4.623921113185371
# customer 168 has arrived at 4.6271855690301 ordering beef
# customer 169 has arrived at 4.635044764173303 ordering veggie
# customer 168 finished ordering
# customer 167 finished ordering
# customer 168 got its beef burger at 4.685098437122786
# customer 167 got its beef burger at 4.68519903760927
# customer 169 finished ordering
# customer 170 has arrived at 4.704004294308352 ordering veggie
# customer 170 finished ordering
# customer 171 has arrived at 4.7190503755159 ordering beef
# customer 172 has arrived at 4.736743438110184 ordering veggie
# customer 171 finished ordering
# customer 172 finished ordering
# customer 169 got its veggie burger at 4.785545700362232
# customer 171 got its beef burger at 4.79438541625302
# customer 170 got its veggie burger at 4.812686552973893
# customer 173 has arrived at 4.844612215223519 ordering beef
# customer 173 finished ordering
# customer 172 got its veggie burger at 4.885545700362232
# customer 173 got its beef burger at 4.894942363421774
# customer 174 has arrived at 4.920428235190489 ordering beef
# customer 175 has arrived at 4.935590541917789 ordering beef
# customer 176 has arrived at 4.963070672844429 ordering veggie
# customer 176 finished ordering
# customer 177 has arrived at 4.972272375044773 ordering beef
# customer 175 finished ordering
# customer 177 finished ordering
# customer 178 has arrived at 5.000250335278073 ordering beef
# customer 178 finished ordering
# customer 179 has arrived at 5.028164812375686 ordering beef
# customer 175 got its beef burger at 5.03032957521838
# customer 180 has arrived at 5.033039339852152 ordering beef
# customer 177 got its beef burger at 5.0373032453405475
# customer 174 finished ordering
# customer 178 got its beef burger at 5.056824094859525
# customer 176 got its veggie burger at 5.0650994715724265
# customer 181 has arrived at 5.105375149536659 ordering beef
# customer 174 got its beef burger at 5.105383872988923
# customer 182 has arrived at 5.129423520925433 ordering beef
# customer 183 has arrived at 5.13019497886878 ordering beef
# customer 181 finished ordering
# customer 180 finished ordering
# customer 184 has arrived at 5.158409917465767 ordering beef
# customer 179 finished ordering
# customer 185 has arrived at 5.170926206588164 ordering beef
# customer 185 finished ordering
# customer 182 finished ordering
# customer 186 has arrived at 5.19773851454981 ordering beef
# customer 186 finished ordering
# customer 181 got its beef burger at 5.201209323710762
# customer 180 got its beef burger at 5.204430730625329
# customer 179 got its beef burger at 5.213233587188587
# customer 183 finished ordering
# customer 184 finished ordering
# customer 185 got its beef burger at 5.2512093237107615
# customer 182 got its beef burger at 5.254430730625328
# customer 186 got its beef burger at 5.263233587188587
# customer 187 has arrived at 5.292235092363866 ordering beef
# customer 183 got its beef burger at 5.301209323710761
# customer 184 got its beef burger at 5.304430730625328
# customer 188 has arrived at 5.330360843787223 ordering beef
# customer 189 has arrived at 5.383060071311181 ordering beef
# customer 189 finished ordering
# customer 190 has arrived at 5.410594979240489 ordering beef
# customer 188 finished ordering
# customer 187 finished ordering
# customer 191 has arrived at 5.450559116151684 ordering beef
# customer 192 has arrived at 5.453760890218024 ordering beef
# customer 192 finished ordering
# customer 189 got its beef burger at 5.459464019630581
# customer 193 has arrived at 5.463571619991604 ordering beef
# customer 188 got its beef burger at 5.4697692961774
# customer 187 got its beef burger at 5.4786373230982495
# customer 194 has arrived at 5.493296032542382 ordering beef
# customer 193 finished ordering
# customer 195 has arrived at 5.500076298760682 ordering beef
# customer 196 has arrived at 5.501976625967067 ordering beef
# customer 190 finished ordering
# customer 192 got its beef burger at 5.509464019630581
# customer 195 finished ordering
# customer 197 has arrived at 5.526132719220777 ordering beef
# customer 194 finished ordering
# customer 193 got its beef burger at 5.547202755670848
# customer 190 got its beef burger at 5.5563738704951895
# customer 197 finished ordering
# customer 191 finished ordering
# customer 195 got its beef burger at 5.567264638596218
# customer 198 has arrived at 5.575888037268146 ordering beef
# customer 199 has arrived at 5.576537451116696 ordering beef
# customer 196 finished ordering
# customer 200 has arrived at 5.589259088971646 ordering beef
# customer 194 got its beef burger at 5.597202755670848
# customer 197 got its beef burger at 5.607978742206103
# customer 199 finished ordering
# customer 201 has arrived at 5.612665372928516 ordering beef
# customer 191 got its beef burger at 5.617264638596218
# customer 198 finished ordering
# customer 200 finished ordering
# customer 202 has arrived at 5.644322491524301 ordering beef
# customer 202 finished ordering
# customer 196 got its beef burger at 5.647202755670848
# customer 203 has arrived at 5.6497694892921135 ordering veggie
# customer 199 got its beef burger at 5.6584275421099495
# customer 198 got its beef burger at 5.669378330035829
# customer 200 got its beef burger at 5.6972027556708476
# customer 204 has arrived at 5.7068465395437755 ordering beef
# customer 205 has arrived at 5.708400537092244 ordering beef
# customer 202 got its beef burger at 5.708427542109949
# customer 206 has arrived at 5.711074048627042 ordering beef
# customer 203 finished ordering
# customer 207 has arrived at 5.719456423441834 ordering beef
# customer 201 finished ordering
# customer 205 finished ordering
# customer 208 has arrived at 5.738824101895291 ordering beef
# customer 206 finished ordering
# customer 209 has arrived at 5.770306895011493 ordering beef
# customer 210 has arrived at 5.773556368999528 ordering veggie
# customer 201 got its beef burger at 5.774436733027527
# customer 211 has arrived at 5.778561533036619 ordering beef
# customer 212 has arrived at 5.781387305124631 ordering beef
# customer 205 got its beef burger at 5.78728603571268
# customer 206 got its beef burger at 5.789062255257842
# customer 208 finished ordering
# customer 209 finished ordering
# customer 203 got its veggie burger at 5.81927835105263
# customer 207 finished ordering
# customer 208 got its beef burger at 5.8516550859589245
# customer 212 finished ordering
# customer 209 got its beef burger at 5.8558846506087665
# customer 213 has arrived at 5.863758879419829 ordering beef
# customer 210 finished ordering
# customer 204 finished ordering
# customer 207 got its beef burger at 5.882748934358555
# customer 214 has arrived at 5.883734160669669 ordering veggie
# customer 211 finished ordering
# customer 212 got its beef burger at 5.902513665031387
# customer 204 got its beef burger at 5.93136448395869
# customer 211 got its beef burger at 5.938190717238079
# customer 214 finished ordering
# customer 215 has arrived at 5.959339173672787 ordering beef
# customer 213 finished ordering
# customer 210 got its veggie burger at 5.977850665467336
# customer 216 has arrived at 6.013237836926638 ordering beef
# customer 213 got its beef burger at 6.02308279391552
# customer 216 finished ordering
# customer 217 has arrived at 6.036841013544377 ordering beef
# customer 214 got its veggie burger at 6.050587892907959
# customer 215 finished ordering
# customer 216 got its beef burger at 6.0791254432053154
# customer 218 has arrived at 6.094411422387198 ordering beef
# customer 218 finished ordering
# customer 215 got its beef burger at 6.123359321319969
# customer 219 has arrived at 6.132324404782009 ordering beef
# customer 220 has arrived at 6.146104237300895 ordering beef
# customer 220 finished ordering
# customer 217 finished ordering
# customer 218 got its beef burger at 6.162433263361094
# customer 221 has arrived at 6.170549039027529 ordering beef
# customer 222 has arrived at 6.175147536900608 ordering beef
# customer 223 has arrived at 6.181254795067822 ordering veggie
# customer 223 finished ordering
# customer 220 got its beef burger at 6.20279837178697
# customer 224 has arrived at 6.206933362269062 ordering beef
# customer 217 got its beef burger at 6.208955345688972
# customer 225 has arrived at 6.213530778842594 ordering beef
# customer 221 finished ordering
# customer 226 has arrived at 6.230698321717393 ordering beef
# customer 219 finished ordering
# customer 226 finished ordering
# customer 224 finished ordering
# customer 227 has arrived at 6.260396260777904 ordering beef
# customer 221 got its beef burger at 6.279439712631969
# customer 223 got its veggie burger at 6.282849625729927
# customer 225 finished ordering
# customer 228 has arrived at 6.292006832313381 ordering beef
# customer 229 has arrived at 6.2954422854167955 ordering veggie
# customer 219 got its beef burger at 6.297619666483278
# customer 227 finished ordering
# customer 226 got its beef burger at 6.3073991073243
# customer 222 finished ordering
# customer 230 has arrived at 6.317033966678495 ordering beef
# customer 231 has arrived at 6.319272738455092 ordering beef
# customer 230 finished ordering
# customer 232 has arrived at 6.329038563278782 ordering beef
# customer 224 got its beef burger at 6.329439712631969
# customer 233 has arrived at 6.330837347297073 ordering beef
# customer 231 finished ordering
# customer 233 finished ordering
# customer 225 got its beef burger at 6.347619666483278
# customer 227 got its beef burger at 6.3573991073243
# customer 232 finished ordering
# customer 234 has arrived at 6.371117898351054 ordering beef
# customer 222 got its beef burger at 6.379439712631969
# customer 229 finished ordering
# customer 230 got its beef burger at 6.397619666483278
# customer 231 got its beef burger at 6.4073991073242995
# customer 234 finished ordering
# customer 235 has arrived at 6.4241409687632975 ordering beef
# customer 233 got its beef burger at 6.429439712631969
# customer 236 has arrived at 6.4339423698254015 ordering beef
# customer 232 got its beef burger at 6.447619666483278
# customer 234 got its beef burger at 6.472888211094293
# customer 235 finished ordering
# customer 229 got its veggie burger at 6.481347803128364
# customer 236 finished ordering
# customer 235 got its beef burger at 6.524896677601613
# customer 236 got its beef burger at 6.55774964653005
# customer 237 has arrived at 6.562429786693084 ordering beef
# customer 238 has arrived at 6.595223424797904 ordering beef
# customer 238 finished ordering
# customer 228 finished ordering
# customer 239 has arrived at 6.615878781301503 ordering beef
# customer 237 finished ordering
# customer 239 finished ordering
# customer 240 has arrived at 6.645158750263209 ordering beef
# customer 241 has arrived at 6.647700612355768 ordering beef
# customer 238 got its beef burger at 6.649358547696785
# customer 228 got its beef burger at 6.657965952837672
# customer 242 has arrived at 6.658376956392905 ordering beef
# customer 237 got its beef burger at 6.666826820757616
# customer 240 finished ordering
# customer 239 got its beef burger at 6.699358547696785
# customer 243 has arrived at 6.72387032371051 ordering beef
# customer 244 has arrived at 6.7280044573435696 ordering beef
# customer 241 finished ordering
# customer 240 got its beef burger at 6.746325378664972
# customer 245 has arrived at 6.747415347313548 ordering beef
# customer 243 finished ordering
# customer 242 finished ordering
# customer 246 has arrived at 6.771841968529091 ordering veggie
# customer 247 has arrived at 6.775257901909813 ordering beef
# customer 241 got its beef burger at 6.791784389591932
# customer 245 finished ordering
# customer 248 has arrived at 6.806096778637154 ordering veggie
# customer 243 got its beef burger at 6.807849399238145
# customer 249 has arrived at 6.813729782116632 ordering beef
# customer 242 got its beef burger at 6.814173132587328
# customer 248 finished ordering
# customer 249 finished ordering
# customer 245 got its beef burger at 6.8464798110001
# customer 246 finished ordering
# customer 247 finished ordering
# customer 250 has arrived at 6.882828564638934 ordering beef
# customer 249 got its beef burger at 6.886288624012082
# customer 251 has arrived at 6.895473750416599 ordering beef
# customer 244 finished ordering
# customer 250 finished ordering
# customer 252 has arrived at 6.913598956717735 ordering beef
# customer 247 got its beef burger at 6.926817173044391
# customer 248 got its veggie burger at 6.93017371464059
# customer 244 got its beef burger at 6.952491730487474
# customer 251 finished ordering
# customer 250 got its beef burger at 6.957135106102107
# customer 252 finished ordering
# customer 246 got its veggie burger at 6.96568206420614
# customer 251 got its beef burger at 7.006658928431318
# customer 252 got its beef burger at 7.009405124245787
# customer 253 has arrived at 7.0348055383517405 ordering beef
# customer 253 finished ordering
# customer 253 got its beef burger at 7.100394783941036
# customer 254 has arrived at 7.101500524866462 ordering veggie
# customer 255 has arrived at 7.11347656533314 ordering beef
# customer 256 has arrived at 7.154464381792076 ordering beef
# customer 257 has arrived at 7.156573915022095 ordering beef
# customer 257 finished ordering
# customer 256 finished ordering
# customer 258 has arrived at 7.186255993796532 ordering beef
# customer 259 has arrived at 7.211864871659936 ordering beef
# customer 254 finished ordering
# customer 257 got its beef burger at 7.219279583246539
# customer 259 finished ordering
# customer 256 got its beef burger at 7.228689839764861
# customer 255 finished ordering
# customer 260 has arrived at 7.261380035243347 ordering beef
# customer 259 got its beef burger at 7.271342752244372
# customer 261 has arrived at 7.284681198988972 ordering beef
# customer 261 finished ordering
# customer 255 got its beef burger at 7.298502093276848
# customer 262 has arrived at 7.302138512694381 ordering beef
# customer 260 finished ordering
# customer 262 finished ordering
# customer 263 has arrived at 7.313591749755799 ordering veggie
# customer 254 got its veggie burger at 7.314882496467177
# customer 263 finished ordering
# customer 264 has arrived at 7.3172222005640135 ordering beef
# customer 261 got its beef burger at 7.347492952885943
# customer 260 got its beef burger at 7.355886711279896
# customer 262 got its beef burger at 7.362689320097399
# customer 264 finished ordering
# customer 265 has arrived at 7.401626646361116 ordering beef
# customer 263 got its veggie burger at 7.41533514175372
# customer 266 has arrived at 7.419264320730549 ordering beef
# customer 264 got its beef burger at 7.420386385001222
# customer 265 finished ordering
# customer 266 finished ordering
# customer 258 finished ordering
# customer 267 has arrived at 7.444863050840486 ordering beef
# customer 268 has arrived at 7.471122971823601 ordering veggie
# customer 268 finished ordering
# customer 265 got its beef burger at 7.47653992824983
# customer 266 got its beef burger at 7.476709287437108
# customer 258 got its beef burger at 7.483828680605004
# customer 269 has arrived at 7.5090628591541995 ordering beef
# customer 267 finished ordering
# customer 269 finished ordering
# customer 267 got its beef burger at 7.559296403140871
# customer 269 got its beef burger at 7.563057785827787
# customer 268 got its veggie burger at 7.5753437857536365
# customer 270 has arrived at 7.6408611585726165 ordering veggie
# customer 270 finished ordering
# customer 271 has arrived at 7.7437436105140405 ordering beef
# customer 272 has arrived at 7.746978820664641 ordering beef
# customer 271 finished ordering
# customer 272 finished ordering
# customer 273 has arrived at 7.776433307412845 ordering veggie
# customer 271 got its beef burger at 7.803973067929612
# customer 272 got its beef burger at 7.804080367568078
# customer 270 got its veggie burger at 7.820031759472626
# customer 273 finished ordering
# customer 274 has arrived at 7.919255304582844 ordering beef
# customer 273 got its veggie burger at 7.923911390908487
# 1750
